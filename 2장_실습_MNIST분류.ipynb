# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
# 1. 데이터셋 생성하기

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# MNIST 데이터 셋 : https://sdc-james.gitbook.io/onebook/4.-and/5.1./5.1.3.-mnist-dataset
# astype(): 타입 변환(정수 -> 실수, 실수 -> 정수)
# 입력이미지는 28*28의 2차원 이미지가 60000개 입력되며 (60000, 28, 28)으로 3차원인데
# reshape() 함수를 통해 2차원 이미지가 784의 1차원 이미지로 변환되고 (60000, 784)으로 2차원 이미지가 됨
# /255.0 => (60000, 28, 28) 모양에 0-255까지 범위에 원소로 가득한 행렬 데이터가
# 0-1 사이에 실수로 가득한 (60000, 784) 모양의 행렬 데이터로 변신하는 과정

x_train = x_train.reshape(60000, 784).astype('float32') / 255.0
x_test = x_test.reshape(10000, 784).astype('float32') / 255.0
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# 2. 모델 구성하기
model = Sequential()
model.add(Dense(units=64, input_dim=28*28, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
# 3. 모델 학습과정 설정하기

model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
# 4. 모델 학습시키기

hist=model.fit(x_train, y_train, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.2265 - accuracy: 0.9365
# Epoch 2/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.2116 - accuracy: 0.9403
# Epoch 3/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1983 - accuracy: 0.9446
# Epoch 4/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1876 - accuracy: 0.9476
# Epoch 5/5
# 60000/60000 [==============================] - 3s 45us/step - loss: 0.1776 - accuracy: 0.9501

# %%
# 5. 학습과정 살펴보기

print("## training loss and acc ##\n")
print("loss --> ", hist.history['loss'])
print("acc --> ", hist.history['accuracy'])
# Out:
# ## training loss and acc ##
#
# loss -->  [0.22645600120425224, 0.2115650787671407, 0.19830707478324572, 0.1875591148406267, 0.17764644748667877]
# acc -->  [0.93645, 0.9403167, 0.9446333, 0.9475833, 0.9501]

# %%
# 6. 모델 평가하기

loss_and_metrics = model.evaluate(x_test, y_test, batch_size=32)
print("\n## evaluation loss and_metrics ##\n")
print(loss_and_metrics)
# Out:
# 10000/10000 [==============================] - 0s 25us/step
#
# ## evaluation loss and_metrics ##
#
# [0.1744476425021887, 0.9484000205993652]

# %%
# 7. 모델 사용하기
# 테스트 셋에 있는 첫 번째 행의 데이터를 예측

xhat = x_test[0:1]
yhat = model.predict(xhat)

print('## yhat ##\n')
print(yhat)
# Out:
# ## yhat ##
#
# [[1.6533808e-05 8.1314944e-08 3.3615527e-04 9.5971138e-04 1.5222724e-07
#   2.2868675e-05 2.6917769e-08 9.9849796e-01 2.1968022e-05 1.4447245e-04]]
