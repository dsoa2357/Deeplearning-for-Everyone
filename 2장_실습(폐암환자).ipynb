# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from keras.models import Sequential
from keras.layers import Dense

# 필요한 라이브러리를 불러옵니다.
import numpy as np
import tensorflow as tf

# %%
# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분입니다.
seed =0
np.random.seed(seed)
tf.random.set_seed(seed)  
# tf.set_random_seed(seed) - 교재에서는 이렇게 썼는데 구글에서는 안 됨

# %%
# 준비된 수술 환자 데이터를 불러들입니다.
Data_set = np.loadtxt("/content/gdrive/My Drive/deepLearning/data/ThoraricSurgery.csv", delimiter=",")

# %%
# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장합니다.
X = Data_set[:,0:17]  # 속성    -> 환자의 기록
Y = Data_set[:,17]    # 클래스  -> 수술 결과

# %%
# 딥러닝 구조를 결정합니다(모델을 설정하고 실행하는 부분입니다).
model = Sequential()
model.add(Dense(30, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# 딥러닝을 실행합니다.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=30, batch_size=10)  # 10개씩 30번 수행
# Out:
# Epoch 1/30
# 470/470 [==============================] - 0s 725us/step - loss: 0.6617 - accuracy: 0.3128
# Epoch 2/30
# 470/470 [==============================] - 0s 112us/step - loss: 0.1488 - accuracy: 0.8511
# Epoch 3/30
# 470/470 [==============================] - 0s 126us/step - loss: 0.1488 - accuracy: 0.8511
# Epoch 4/30
# 470/470 [==============================] - 0s 119us/step - loss: 0.1488 - accuracy: 0.8511
# Epoch 5/30
# 470/470 [==============================] - 0s 145us/step - loss: 0.1488 - accuracy: 0.8511
# Epoch 6/30
# 470/470 [==============================] - 0s 125us/step - loss: 0.1487 - accuracy: 0.8511
# Epoch 7/30
# 470/470 [==============================] - 0s 110us/step - loss: 0.1487 - accuracy: 0.8511
# Epoch 8/30
# 470/470 [==============================] - 0s 128us/step - loss: 0.1487 - accuracy: 0.8511
# Epoch 9/30
# 470/470 [==============================] - 0s 144us/step - loss: 0.1487 - accuracy: 0.8511
# Epoch 10/30
# ...

# %%
# 결과를 출력합니다.
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))  # %.4f: 소수점 4자리까지
# Out:
# 470/470 [==============================] - 0s 66us/step
#
#  Accuracy: 0.8511
