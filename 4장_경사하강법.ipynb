# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# import tensorflow as tf (버전2 오류)

import tensorflow.compat.v1 as tf  # 버전1로 실행
tf.disable_v2_behavior()

#tf.__version__
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# x, y의 데이터 값

data = [[2, 81], [4, 93], [6, 91], [8, 97]]
x_data = [x_row[0] for x_row in data]
y_data = [y_row[1] for y_row in data]

# %%
# 기울기 a와 절편 b의 값을 임의로 정한다.
# 단, 기울기의 범위는 0~10 사이이며, y 절편은 0~100 사이에서 변하게 한다.
# tf.random_uniform --> tf.random.uniform으로 변경

a = tf.Variable(tf.random_uniform([1], 0, 10,  dtype=tf.float64, seed = 0))
b = tf.Variable(tf.random_uniform([1], 0, 100, dtype=tf.float64, seed = 0))

# %%
# y에 대한 일치 방정식 ax+b의 식을 세운다.

y = a * x_data + b

# %%
# 텐서플로 rmse 함수

rmse = tf.sqrt(tf.reduce_mean(tf.square(y - y_data)))

# %%
# rmse 값을 최소로 하는 값 찾기

gradient_decent = tf.train.GradientDescentOptimizer(learning_rate = 0.1).minimize(rmse)

# %%
with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())

  for step in range(2001):
    sess.run(gradient_decent)
    if step % 100 == 0:
      print("Epoch: %4d, RMSE = %7.4f, 기울기 a =%7.4f, y 절편 =%8.4f" %(step, sess.run(rmse), sess.run(a), sess.run(b)))
# Out:
# Epoch:    0, RMSE = 30.2139, 기울기 a = 7.5235, y 절편 = 80.5984
# Epoch:  100, RMSE =  2.8860, 기울기 a = 2.2299, y 절편 = 79.4181
# Epoch:  200, RMSE =  2.8826, 기울기 a = 2.2601, y 절편 = 79.2379
# Epoch:  300, RMSE =  2.8815, 기울기 a = 2.2773, y 절편 = 79.1353
# Epoch:  400, RMSE =  2.8811, 기울기 a = 2.2871, y 절편 = 79.0770
# Epoch:  500, RMSE =  2.8810, 기울기 a = 2.2927, y 절편 = 79.0438
# Epoch:  600, RMSE =  2.8810, 기울기 a = 2.2958, y 절편 = 79.0249
# Epoch:  700, RMSE =  2.8810, 기울기 a = 2.2976, y 절편 = 79.0142
# Epoch:  800, RMSE =  2.8810, 기울기 a = 2.2987, y 절편 = 79.0081
# Epoch:  900, RMSE =  2.8810, 기울기 a = 2.2992, y 절편 = 79.0046
# Epoch: 1000, RMSE =  2.8810, 기울기 a = 2.2996, y 절편 = 79.0026
# Epoch: 1100, RMSE =  2.8810, 기울기 a = 2.2998, y 절편 = 79.0015
# Epoch: 1200, RMSE =  2.8810, 기울기 a = 2.2999, y 절편 = 79.0008
# Epoch: 1300, RMSE =  2.8810, 기울기 a = 2.2999, y 절편 = 79.0005
# Epoch: 1400, RMSE =  2.8810, 기울기 a = 2.3000, y 절편 = 79.0003
# Epoch: 1500, RMSE =  2.8810, 기울기 a = 2.3000, y 절편 = 79.0002
# ...
